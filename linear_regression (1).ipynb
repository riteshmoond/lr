# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.state.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5ebc32fe86fc> in <cell line: 1>()
# ----> 1 df.state.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'state'

# %%
len(df.state.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d36a33539210> in <cell line: 1>()
# ----> 1 len(df.state.unique())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'state'

# %%
# x = year
# y = total production

# %%
df.year.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ce47b7d00b50> in <cell line: 1>()
# ----> 1 df.year.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %%
df.totalprod.describe()

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.scattere(df.year , df.totalprod)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-71595fc3d6ea> in <cell line: 1>()
# ----> 1 df.scattere(df.year , df.totalprod)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scattere'

# %%
import matplotlib.pyplot as plt


x = df["year"]
y = df["totalprod"]


plt.figure(figsize=(10, 6))
plt.scatter(x, y, color="blue", marker="o", alpha=0.7)

plt.title("Scatter Plot of Total Production vs Year")
plt.xlabel("Year")
plt.ylabel("Total Production")
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt

# Get the data from somewhere (e.g., a dataframe)
totalprod = df["totalprod"]

# Create the histogram
plt.hist(totalprod)

# Add labels and title
plt.xlabel("Totalprod")
plt.ylabel("Frequency")
plt.title("Histogram of Totalprod")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Get the data from somewhere (e.g., a dataframe)
year = df["year"]

# Create the histogram
plt.hist(year)

# Add labels and title
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.title("Histogram of Year")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import LinearRegression

regr = LinearRegression()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Mean और standard deviation सेट करें
mean = 0
std_dev = 1

# Normal distribution से 1000 random samples जनरेट करें
samples = np.random.normal(mean, std_dev, 1000)

# Histogram प्लॉट करें
plt.hist(samples, bins=30, density=True, alpha=0.6, color='g')

# Normal distribution की PDF प्लॉट करें
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = np.exp(-0.5*((x-mean)/std_dev)**2) / (std_dev * np.sqrt(2*np.pi))

plt.plot(x, p, 'k', linewidth=2)
plt.title('Normal Distribution')
plt.show()
